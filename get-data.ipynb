# %%
from main import main

# %%
main()
# Out:
# 2019-11-10 20:41:08,562 (cycling_data_downloader.py:36): (INFO) Remaining 413 files, downloading https://s3-eu-west-1.amazonaws.com/cycling.data.tfl.gov.uk/CycleCounters/Blackfriars/July/Friday, Jul 13 2018.xls
# 2019-11-10 20:41:08,563 (cycling_data_downloader.py:36): (INFO) Remaining 412 files, downloading https://s3-eu-west-1.amazonaws.com/cycling.data.tfl.gov.uk/CycleCounters/Blackfriars/July/Friday, Jul 20 2018.xls
# 2019-11-10 20:41:08,564 (cycling_data_downloader.py:36): (INFO) Remaining 411 files, downloading https://s3-eu-west-1.amazonaws.com/cycling.data.tfl.gov.uk/CycleCounters/Blackfriars/July/Friday, Jul 27 2018.xls
# 2019-11-10 20:41:08,566 (cycling_data_downloader.py:36): (INFO) Remaining 410 files, downloading https://s3-eu-west-1.amazonaws.com/cycling.data.tfl.gov.uk/CycleCounters/Blackfriars/July/Friday, Jul 6 2018.xls
# ...
